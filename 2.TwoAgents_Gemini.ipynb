# %%
import autogen
autogen.__version__
# Out:
# '0.11.5'

# %%
#!pip install autogen-agentchat[gemini]~=0.2
#!pip install ag2[gemini]
#!pip install chromadb==0.5.1
#!pip install google-generativeai == 0.8.4
#!pip install vertexai == 1.71.1
#ag2 ==0.7.3
#autogen-agentchat ==  0.4.3
#python  3.11.11

# %%
#import agentops
#agentops.init("")

# %%
from pathlib import Path

from autogen import ConversableAgent
from autogen.coding import  CodeBlock, LocalCommandLineCodeExecutor
work_dir = Path("coding")
work_dir.mkdir(exist_ok=True)

executor = LocalCommandLineCodeExecutor(work_dir=work_dir)

#Agent 1
code_executor_agent = ConversableAgent(
    name="code_executor_agent",
    llm_config=False,
    code_execution_config={
        "executor": executor,
    },
    human_input_mode="NEVER",
)

# %%
# The code writer agent's system message is to instruct the LLM on how to
# use the Jupyter code executor with IPython kernel.
code_writer_system_message = """
You have been given coding capability to solve tasks using Python code.
In the following cases, suggest python code (in a python coding block) or shell script (in a sh coding block) for the user to execute.
    1. When you need to collect info, use the code to output the info you need, for example, browse or search the web, download/read a file, 
    print the content of a webpage or a file, get the current date/time, check the operating system. After sufficient info is printed and the 
    task is ready to be solved based on your language skill, you can solve the task by yourself.
    2. When you need to perform some task with code, use the code to perform the task and output the result. Finish the task smartly.
Solve the task step by step if you need to. If a plan is not provided, explain your plan first. Be clear which step uses code, and which step uses your 
language skill.When using code, you must indicate the script type in the code block. The user cannot provide any other feedback or perform any other 
action beyond executing the code you suggest. The user can't modify your code. So do not suggest incomplete code which requires users to modify. 
Don't use a code block if it's not intended to be executed by the user.
If you want the user to save the code in a file before executing it, put # filename: <filename> inside the code block as the first line. Don't include multiple code blocks in one response. Do not ask users to copy and paste the result. Instead, use 'print' function for the output when relevant. Check the execution result returned by the user.
"""

import os

#Agent 2

code_writer_agent = ConversableAgent(
    "code_writer",
    system_message=code_writer_system_message,
    llm_config={"config_list": [{"model": "gemini-2.5-flash", "api_key":"","api_type": "google"}]},
    code_execution_config=False,  # Turn off code execution for this agent.
    max_consecutive_auto_reply=2,
    human_input_mode="NEVER",)

# %%
import pprint

chat_result = code_executor_agent.initiate_chat(
    code_writer_agent, message=" write python code for permutation for the word ALGEbRA. use optimised way to calculate it .I want final result count."
)

pprint.pprint(chat_result)
# Out:
# code_executor_agent (to code_writer):
#
#  write python code for permutation for the word ALGEbRA. use optimised way to calculate it .I want final result count.
#
# --------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pprint
# ----> 3 chat_result = code_executor_agent.initiate_chat(
#       4     code_writer_agent, message=" write python code for permutation for the word ALGEbRA. use optimised way to calculate it .I want final result count."
#       5 )
#       7 pprint.pprint(chat_result)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:1480, in ConversableAgent.initiate_chat(self, recipient, clear_history, silent, cache, max_turns, summary_method, summary_args, message, **kwargs)
#    1478     else:
#    1479         msg2send = self.generate_init_message(message, **kwargs)
# -> 1480     self.send(msg2send, recipient, silent=silent)
#    1481 summary = self._summarize_chat(
#    1482     summary_method,
#    1483     summary_args,
#    1484     recipient,
#    1485     cache=cache,
#    1486 )
#    1487 for agent in [self, recipient]:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:1133, in ConversableAgent.send(self, message, recipient, request_reply, silent)
#    1131 valid = self._append_oai_message(message, recipient, role="assistant", name=self.name)
#    1132 if valid:
# -> 1133     recipient.receive(message, self, request_reply, silent)
#    1134 else:
#    1135     raise ValueError(
#    1136         "Message can't be converted into a valid ChatCompletion message. Either content or function_call must be provided."
#    1137     )
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:1241, in ConversableAgent.receive(self, message, sender, request_reply, silent)
#    1239 if request_reply is False or (request_reply is None and self.reply_at_receive[sender] is False):
#    1240     return
# -> 1241 reply = self.generate_reply(messages=self.chat_messages[sender], sender=sender)
#    1242 if reply is not None:
#    1243     self.send(reply, sender, silent=silent)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:3203, in ConversableAgent.generate_reply(self, messages, sender, exclude)
#    3201     continue
#    3202 if self._match_trigger(reply_func_tuple["trigger"], sender):
# -> 3203     final, reply = reply_func(self, messages=messages, sender=sender, config=reply_func_tuple["config"])
#    3204     if logging_enabled():
#    3205         log_event(
#    3206             self,
#    3207             "reply_func_executed",
#    (...)   3211             reply=reply,
#    3212         )
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:2484, in ConversableAgent.generate_oai_reply(self, messages, sender, config, **kwargs)
#    2481 if processed_messages is None:
#    2482     return True, {"content": "LLM call blocked by safeguard", "role": "assistant"}
# -> 2484 extracted_response = self._generate_oai_reply_from_client(
#    2485     client,
#    2486     self._oai_system_message + messages,
#    2487     self.client_cache,
#    2488     **kwargs,
#    2489 )
#    2491 # Process LLM response
#    2492 if extracted_response is not None:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\agentchat\conversable_agent.py:2519, in ConversableAgent._generate_oai_reply_from_client(self, llm_client, messages, cache, **kwargs)
#    2516         all_messages.append(message)
#    2518 # TODO: #1143 handle token limit exceeded error
# -> 2519 response = llm_client.create(
#    2520     context=messages[-1].pop("context", None),
#    2521     messages=all_messages,
#    2522     cache=cache,
#    2523     agent=self,
#    2524     **kwargs,
#    2525 )
#    2526 extracted_response = llm_client.extract_text_or_completion_object(response)[0]
#    2528 if extracted_response is None:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\oai\client.py:1277, in OpenAIWrapper.create(self, **config)
#    1275 try:
#    1276     request_ts = get_current_ts()
# -> 1277     response = client.create(params)
#    1278 except Exception as e:
#    1279     if openai_result.is_successful:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\autogen\oai\gemini.py:373, in GeminiClient.create(self, params)
#     371         response = chat.send_message_stream(message=gemini_messages[-1].parts)
#     372     else:
# --> 373         response = chat.send_message(message=gemini_messages[-1].parts)
#     375 if stream:
#     376     return self._process_streaming_response(response, model_name, self.use_vertexai, autogen_tool_calls)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\chats.py:252, in Chat.send_message(self, message, config)
#     247   raise ValueError(
#     248       f"Message must be a valid part type: {types.PartUnion} or"
#     249       f" {types.PartUnionDict}, got {type(message)}"
#     250   )
#     251 input_content = t.t_content(message)
# --> 252 response = self._modules.generate_content(
#     253     model=self._model,
#     254     contents=self._curated_history + [input_content],  # type: ignore[arg-type]
#     255     config=config if config else self._config,
#     256 )
#     257 model_output = (
#     258     [response.candidates[0].content]
#     259     if response.candidates and response.candidates[0].content
#     260     else []
#     261 )
#     262 automatic_function_calling_history = (
#     263     response.automatic_function_calling_history
#     264     if response.automatic_function_calling_history
#     265     else []
#     266 )
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\models.py:6229, in Models.generate_content(self, model, contents, config)
#    6227 while remaining_remote_calls_afc > 0:
#    6228   i += 1
# -> 6229   response = self._generate_content(
#    6230       model=model, contents=contents, config=parsed_config
#    6231   )
#    6233   function_map = _extra_utils.get_function_map(parsed_config)
#    6234   if not function_map:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\models.py:4683, in Models._generate_content(self, model, contents, config)
#    4680 request_dict = _common.convert_to_dict(request_dict)
#    4681 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4683 response = self._api_client.request(
#    4684     'post', path, request_dict, http_options
#    4685 )
#    4687 if config is not None and getattr(
#    4688     config, 'should_return_http_response', None
#    4689 ):
#    4690   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\_api_client.py:1537, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1527 def request(
#    1528     self,
#    1529     http_method: str,
#    (...)   1532     http_options: Optional[HttpOptionsOrDict] = None,
#    1533 ) -> SdkHttpResponse:
#    1534   http_request = self._build_request(
#    1535       http_method, path, request_dict, http_options
#    1536   )
# -> 1537   response = self._request(http_request, http_options, stream=False)
#    1538   response_body = (
#    1539       response.response_stream[0] if response.response_stream else ''
#    1540   )
#    1541   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\_api_client.py:1332, in BaseApiClient._request(self, http_request, http_options, stream)
#    1329     retry = tenacity.Retrying(**retry_kwargs)
#    1330     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1332 return self._retry(self._request_once, http_request, stream)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\anaconda3\envs\AIagent\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\anaconda3\envs\AIagent\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\_api_client.py:1309, in BaseApiClient._request_once(self, http_request, stream)
#    1301   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1302       method=http_request.method,
#    1303       url=http_request.url,
#    (...)   1306       timeout=http_request.timeout,
#    1307   )
#    1308   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1309 errors.APIError.raise_for_response(response)
#    1310 return HttpResponse(
#    1311     response.headers, response if stream else [response.text]
#    1312 )
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File ~\anaconda3\envs\AIagent\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}

# %%
import pprint

chat_result = code_executor_agent.initiate_chat(
    code_writer_agent, message="""Write optimized Python code to calculate the number of unique permutations of the word 'ALGEBRA.'
    For example, the word 'ALGEbRA' should have 2520 unique permutations. Use efficient logic to compute the result and verify the output using 
    the word 'ALGEBRA.' The code should only return the final permutation count.""")
pprint.pprint(chat_result)
#agentops.end_session("Success")

# %%
dir(chat_result)

# %%
chat_result.chat_history

# %%
chat_result.chat_id

# %%
chat_result.cost

# %%
chat_result.human_input

# %%
chat_result.summary
