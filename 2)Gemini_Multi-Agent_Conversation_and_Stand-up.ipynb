# %% [markdown]
# ## Setup

# %%
#LLM configuration
llm_config = {"model": "models/gemini-2.5-flash","api_key":"","api_type":"google"}

# %% [markdown]
# ## Define an AutoGen agent

# %%
from autogen import ConversableAgent

agent = ConversableAgent(
    name="chatbot",
    llm_config=llm_config,
    human_input_mode="NEVER",
)
# Out:
# Patching name='__init__', member=<function LLMLingua.__init__ at 0x000001C1F85728E0>, patched=<function function.__call__ at 0x000001C1F8572840>
# Patching name='compress_text', member=<function LLMLingua.compress_text at 0x000001C1F8572980>, patched=<function function.__call__ at 0x000001C1F8572C00>

# %%
reply = agent.generate_reply(
    messages=[{"content": "Tell me a joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Why don't scientists trust atoms?\n\nBecause they make up everything!", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}
# C:\Users\PAVAN\anaconda3\envs\AIagent\Lib\site-packages\autogen\oai\gemini.py:803: UserWarning: Cost calculation is not implemented for model models/gemini-2.5-flash. Cost will be calculated zero.
#   warnings.warn(

# %%
reply = agent.generate_reply(
    messages=[{"content": "Repeat the joke.", "role": "user"}]
)
print(reply)
# Out:
# {'content': "Please tell me the joke first! I'm ready to repeat it once you share it with me.", 'refusal': None, 'role': 'assistant', 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': None}

# %% [markdown]
# ## Conversation
# Setting up a conversation between two agents, Cathy and Joe, where the memory of their interactions is retained.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "Start the next joke from the punchline of the previous joke.",
    llm_config=llm_config,
    human_input_mode="NEVER",
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.",
    max_turns=2,
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe, you got it! "Keep the jokes rolling," you say? Sounds like my therapist trying to get me to process my childhood trauma – it's a slow, creaky process, but eventually, we get there!
#
# Speaking of slow and creaky, I tried to do yoga the other day. The instructor said, "Find your center." I said, "Lady, my center is currently wherever the nearest pizza is, and that ain't in this room." My downward-facing dog looked more like a bewildered golden retriever trying to figure out a new puzzle toy.
#
# And don't even get me started on dating apps. My profile says, "Looking for someone who can make me laugh." Apparently, the algorithm just shows me pictures of myself from high school. Tough crowd, Joe, tough crowd!
#
# What's next, a rimshot? You want another one? I'm just getting warmed up!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Tough crowd, Cathy? You think *that's* tough? I recently performed at a convention for professional poker players. Trying to get a laugh out of *that* room... I swear, I could've told them their mothers were giving away free gold, and all I'd get was a slow blink and 'fold.'
#
# And speaking of tough crowds, I tried to get my cat to fetch the other day. I threw the toy, he looked at me, then looked at the toy, and then just... went back to sleep. I think his profile pic would just be a blurry shot of a half-eaten tuna can. Talk about a tough critic!
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, Joe, you're a brave, brave man! Performing for poker players? That's not a tough crowd, that's an *emotional void*. I bet even a fire alarm going off would just get a casual "check" from those guys. A slow blink and 'fold'? That's basically their version of a standing ovation! "Your mother giving away free gold" – I'm surprised they didn't just ask for the coordinates and then silently judge her distribution strategy.
#
# And your cat! Oh, I know that look. Mine gives me that same "you amuse me not" stare every morning. I swear, he thinks *my* life is the joke. He's probably got a secret blog, "My Human's Pitiful Attempts at Entertainment," and your half-eaten tuna can profile pic is probably a *compliment* compared to what he'd write about me. "Subject tried to tell a knock-knock joke. Knocked on the door to *my* nap zone. Unacceptable."
#
# You know, the only crowd tougher than professional poker players or a disinterested feline... is my own *dentist*. I tried to tell him a joke during my last cleaning – you know, trying to lighten the mood while he's got his hands in my mouth – and all I got was a muffled "mhmmph" and a squirt of water. I think he was just trying to get me to spit out the punchline.
#
# Now *that's* a tough room! At least the poker players eventually fold... and the cat eventually *might* acknowledge your existence for food. The dentist just moves on to the next tooth.
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Print some results
#
# You can print out:
#
# 1. Chat history
# 2. Cost
# 3. Summary of the conversation

# %%
import pprint

pprint.pprint(chat_result.chat_history)
# Out:
# [{'content': "I'm Joe. Cathy, let's keep the jokes rolling.",
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': 'Alright, Joe, you got it! "Keep the jokes rolling," you say? '
#              'Sounds like my therapist trying to get me to process my '
#              "childhood trauma – it's a slow, creaky process, but eventually, "
#              'we get there!\n'
#              '\n'
#              'Speaking of slow and creaky, I tried to do yoga the other day. '
#              'The instructor said, "Find your center." I said, "Lady, my '
#              'center is currently wherever the nearest pizza is, and that '
#              'ain\'t in this room." My downward-facing dog looked more like a '
#              'bewildered golden retriever trying to figure out a new puzzle '
#              'toy.\n'
#              '\n'
#              "And don't even get me started on dating apps. My profile says, "
#              '"Looking for someone who can make me laugh." Apparently, the '
#              'algorithm just shows me pictures of myself from high school. '
#              'Tough crowd, Joe, tough crowd!\n'
#              '\n'
#              "What's next, a rimshot? You want another one? I'm just getting "
#              'warmed up!',
#   'name': 'cathy',
#   'role': 'user'},
#  {'content': "Tough crowd, Cathy? You think *that's* tough? I recently "
#              'performed at a convention for professional poker players. Trying '
#              "to get a laugh out of *that* room... I swear, I could've told "
#              "them their mothers were giving away free gold, and all I'd get "
#              "was a slow blink and 'fold.'\n"
#              '\n'
#              'And speaking of tough crowds, I tried to get my cat to fetch the '
#              'other day. I threw the toy, he looked at me, then looked at the '
#              'toy, and then just... went back to sleep. I think his profile '
#              'pic would just be a blurry shot of a half-eaten tuna can. Talk '
#              'about a tough critic!',
#   'name': 'joe',
#   'role': 'assistant'},
#  {'content': "Joe, Joe, you're a brave, brave man! Performing for poker "
#              "players? That's not a tough crowd, that's an *emotional void*. I "
#              'bet even a fire alarm going off would just get a casual "check" '
#              "from those guys. A slow blink and 'fold'? That's basically their "
#              'version of a standing ovation! "Your mother giving away free '
#              'gold" – I\'m surprised they didn\'t just ask for the coordinates '
#              'and then silently judge her distribution strategy.\n'
#              '\n'
#              'And your cat! Oh, I know that look. Mine gives me that same "you '
#              'amuse me not" stare every morning. I swear, he thinks *my* life '
#              'is the joke. He\'s probably got a secret blog, "My Human\'s '
#              'Pitiful Attempts at Entertainment," and your half-eaten tuna can '
#              "profile pic is probably a *compliment* compared to what he'd "
#              'write about me. "Subject tried to tell a knock-knock joke. '
#              'Knocked on the door to *my* nap zone. Unacceptable."\n'
#              '\n'
#              'You know, the only crowd tougher than professional poker players '
#              'or a disinterested feline... is my own *dentist*. I tried to '
#              'tell him a joke during my last cleaning – you know, trying to '
#              "lighten the mood while he's got his hands in my mouth – and all "
#              'I got was a muffled "mhmmph" and a squirt of water. I think he '
#              'was just trying to get me to spit out the punchline.\n'
#              '\n'
#              "Now *that's* a tough room! At least the poker players eventually "
#              'fold... and the cat eventually *might* acknowledge your '
#              'existence for food. The dentist just moves on to the next tooth.',
#   'name': 'cathy',
#   'role': 'user'}]

# %%
pprint.pprint(chat_result.cost)
# Out:
# {'usage_excluding_cached_inference': {'models/gemini-2.5-flash': {'completion_tokens': 678,
#                                                                   'cost': 0,
#                                                                   'prompt_tokens': 629,
#                                                                   'total_tokens': 1307},
#                                       'total_cost': 0},
#  'usage_including_cached_inference': {'models/gemini-2.5-flash': {'completion_tokens': 678,
#                                                                   'cost': 0,
#                                                                   'prompt_tokens': 629,
#                                                                   'total_tokens': 1307},
#                                       'total_cost': 0}}

# %%
pprint.pprint(chat_result.summary)
# Out:
# ("Joe, Joe, you're a brave, brave man! Performing for poker players? That's "
#  "not a tough crowd, that's an *emotional void*. I bet even a fire alarm going "
#  'off would just get a casual "check" from those guys. A slow blink and '
#  '\'fold\'? That\'s basically their version of a standing ovation! "Your '
#  'mother giving away free gold" – I\'m surprised they didn\'t just ask for the '
#  'coordinates and then silently judge her distribution strategy.\n'
#  '\n'
#  'And your cat! Oh, I know that look. Mine gives me that same "you amuse me '
#  'not" stare every morning. I swear, he thinks *my* life is the joke. He\'s '
#  'probably got a secret blog, "My Human\'s Pitiful Attempts at Entertainment," '
#  'and your half-eaten tuna can profile pic is probably a *compliment* compared '
#  'to what he\'d write about me. "Subject tried to tell a knock-knock joke. '
#  'Knocked on the door to *my* nap zone. Unacceptable."\n'
#  '\n'
#  'You know, the only crowd tougher than professional poker players or a '
#  'disinterested feline... is my own *dentist*. I tried to tell him a joke '
#  "during my last cleaning – you know, trying to lighten the mood while he's "
#  'got his hands in my mouth – and all I got was a muffled "mhmmph" and a '
#  'squirt of water. I think he was just trying to get me to spit out the '
#  'punchline.\n'
#  '\n'
#  "Now *that's* a tough room! At least the poker players eventually fold... and "
#  'the cat eventually *might* acknowledge your existence for food. The dentist '
#  'just moves on to the next tooth.')

# %% [markdown]
# ## Get a better summary of the conversation

# %%
chat_result = joe.initiate_chat(
    cathy, 
    message="I'm Joe. Cathy, let's keep the jokes rolling.", 
    max_turns=2, 
    summary_method="reflection_with_llm",
    summary_prompt="Summarize the conversation",
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe, you got it! "Keep the jokes rolling," you say? Sounds like my therapist trying to get me to process my childhood trauma – it's a slow, creaky process, but eventually, we get there!
#
# Speaking of slow and creaky, I tried to do yoga the other day. The instructor said, "Find your center." I said, "Lady, my center is currently wherever the nearest pizza is, and that ain't in this room." My downward-facing dog looked more like a bewildered golden retriever trying to figure out a new puzzle toy.
#
# And don't even get me started on dating apps. My profile says, "Looking for someone who can make me laugh." Apparently, the algorithm just shows me pictures of myself from high school. Tough crowd, Joe, tough crowd!
#
# What's next, a rimshot? You want another one? I'm just getting warmed up!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Tough crowd, Cathy? You think *that's* tough? I recently performed at a convention for professional poker players. Trying to get a laugh out of *that* room... I swear, I could've told them their mothers were giving away free gold, and all I'd get was a slow blink and 'fold.'
#
# And speaking of tough crowds, I tried to get my cat to fetch the other day. I threw the toy, he looked at me, then looked at the toy, and then just... went back to sleep. I think his profile pic would just be a blurry shot of a half-eaten tuna can. Talk about a tough critic!
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, Joe, you're a brave, brave man! Performing for poker players? That's not a tough crowd, that's an *emotional void*. I bet even a fire alarm going off would just get a casual "check" from those guys. A slow blink and 'fold'? That's basically their version of a standing ovation! "Your mother giving away free gold" – I'm surprised they didn't just ask for the coordinates and then silently judge her distribution strategy.
#
# And your cat! Oh, I know that look. Mine gives me that same "you amuse me not" stare every morning. I swear, he thinks *my* life is the joke. He's probably got a secret blog, "My Human's Pitiful Attempts at Entertainment," and your half-eaten tuna can profile pic is probably a *compliment* compared to what he'd write about me. "Subject tried to tell a knock-knock joke. Knocked on the door to *my* nap zone. Unacceptable."
#
# You know, the only crowd tougher than professional poker players or a disinterested feline... is my own *dentist*. I tried to tell him a joke during my last cleaning – you know, trying to lighten the mood while he's got his hands in my mouth – and all I got was a muffled "mhmmph" and a squirt of water. I think he was just trying to get me to spit out the punchline.
#
# Now *that's* a tough room! At least the poker players eventually fold... and the cat eventually *might* acknowledge your existence for food. The dentist just moves on to the next tooth.
#
# --------------------------------------------------------------------------------

# %%
pprint.pprint(chat_result.summary)
# Out:
# {'annotations': None,
#  'audio': None,
#  'content': 'The conversation between Joe and Cathy revolves around the shared '
#             'experience of encountering "tough crowds" in various contexts. '
#             'They joke about the difficulty of getting a reaction from '
#             'professional poker players, a disinterested cat, and even a '
#             'dentist during a cleaning, highlighting the challenge and humor '
#             'in these unreactive audiences.',
#  'function_call': None,
#  'refusal': None,
#  'role': 'assistant',
#  'tool_calls': None}

# %% [markdown]
# ## Chat Termination
#
# Chat can be terminated using a termination conditions.

# %%
cathy = ConversableAgent(
    name="cathy",
    system_message=
    "Your name is Cathy and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"],
)

joe = ConversableAgent(
    name="joe",
    system_message=
    "Your name is Joe and you are a stand-up comedian. "
    "When you're ready to end the conversation, say 'I gotta go'.",
    llm_config=llm_config,
    human_input_mode="NEVER",
    is_termination_msg=lambda msg: "I gotta go" in msg["content"] or "Goodbye" in msg["content"],
)

# %%
chat_result = joe.initiate_chat(
    recipient=cathy,
    message="I'm Joe. Cathy, let's keep the jokes rolling."
)
# Out:
# joe (to cathy):
#
# I'm Joe. Cathy, let's keep the jokes rolling.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Alright, Joe! You got it! The jokes don't stop 'til I run out of coffee or inspiration, whichever comes first. Usually coffee.
#
# Speaking of, you ever notice how adulting is just constantly trying to figure out if you have enough money to buy something *and* if you have enough energy to go get it? It's like a two-factor authentication for every single desire.
#
# Like, I saw this really cool lamp online the other day. My apartment desperately needs more light. And I thought, 'Oh, I can totally afford that!' *But can I physically go to the store and bring it home?* No. No, Cathy, you cannot. You must now wait until you can rope a friend into helping, or until you suddenly develop an inexplicable burst of upper body strength. The lamp remains in my cart, mocking me.
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Cathy, you are speaking my language! That lamp in your cart isn't just a lamp, it's a monument to the adult dilemma! The holy trinity of 'want it, can afford it, but the *effort*?!'
#
# I had the exact same thing with a new bed frame last month. My old one was creaking like a pirate ship in a hurricane, seriously. Could I afford a new, silent, majestic sleep palace? Absolutely. Could I navigate a furniture store, transport it, and then assemble it without losing a finger or my sanity? That, my friends, is where the credit card stops, and the existential dread begins.
#
# So I'm sleeping on this noisy deathtrap, constantly reminded that I could afford comfort... if only comfort didn't require me to *lift things*. It's a cruel joke, I tell ya. My Amazon cart is basically a museum of my unfulfilled adult potential. And the shipping cost? That's just the "energy tax" they tack on for our weakness.
#
# You know, sometimes I just wonder if my ancestors fought saber-toothed tigers just so *I* could debate whether putting on pants counts as 'going out' for the night. The sacrifices we make.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Oh, Joe, you hit the nail right on the head! "A monument to the adult dilemma!" That's going on my tombstone, right next to "She almost assembled that IKEA shelf." You're right, the shipping cost *is* the energy tax! They're not charging for the fuel, they're charging for the five minutes I just spent debating if I *really* need those new socks or if I can just wear my existing ones inside out.
#
# And your bed frame? A pirate ship in a hurricane! That's brilliant. My shower curtain rod is doing the same thing. Every time I pull the curtain, it's a dramatic reenactment of a maritime disaster. I could replace it... but then I'd have to get out a step stool. And I'd have to find the right size. And then screw it in. And then dispose of the old one. So for now, every shower is just me mentally preparing for a plank walk.
#
# You're so right about our ancestors! They were out there fighting saber-toothed tigers, foraging for berries, building fires with two sticks and a dream... and here I am, debating if I have the *emotional fortitude* to cook the chicken I bought two days ago, or if it's just easier to order a pizza. The chicken is *right there*. It just requires... *effort*. It's a whole journey from fridge to plate, involving pans, spices, maybe even *chopping* something. My ancestors would look at me and be like, "Cathy, we crossed continents for less effort than it takes you to preheat an oven!"
#
# I swear, my biggest modern "survival skill" is simply being able to convincingly argue myself out of doing chores. It's a full-time job. I'm practically a lawyer in my own head. "Your honor, the defendant submits that the dishes can indeed wait until tomorrow, as the current energy levels are insufficient for proper scrubbing, and a risk of 'burnout' is imminent!" The jury (my cat) always agrees.
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# "She almost assembled that IKEA shelf!" Cathy, that's not a tombstone inscription, that's a *hero's epitaph*! It describes the struggle of our generation! IKEA furniture isn't designed to be assembled, it's designed to make you question every life choice that led you to that moment, holding a tiny allen wrench, staring at a diagram that looks like a riddle from a forgotten civilization. And then you have three extra screws at the end, and you're like, "Did I just build a shelf, or a ticking time bomb?"
#
# And that energy tax? It's real! My bank statements just say "Amazon Prime - Energy Tariff for Existential Dread." And your shower curtain rod? Oh man, I *know* that struggle. Mine isn't a pirate ship, it's more like a dramatic opera, with the curtain rods *wailing* every time you pull them. I just embrace it now. It adds character. My guests sometimes ask if I live in a haunted house. I tell them, "No, just a house that requires *active maintenance*." The horror!
#
# And the chicken! Oh, the chicken. That journey from fridge to plate isn't just a journey, it's an *epic quest*. You have to thaw it, which is basically an act of faith. Then you have to touch it – cold, slimy, raw meat, the stuff of nightmares! Then the spices, the pan, the *chopping* – my ancestors didn't fight saber-toothed tigers to teach me knife skills; they fought so I could have convenient protein delivery services!
#
# You're a lawyer in your own head, Cathy? I'm practically running a high-stakes arbitration tribunal in mine! "Your Honor, the prosecution (my conscience) asserts that the floor has reached a critical dust-bunny mass. However, the defense (my couch) argues that a 'rest and digest' period is crucial for optimal cognitive function, thereby postponing the aforementioned dust-bunny remediation until a period of increased energy, which, as yet, remains undefined." The jury (my dog) always barks in agreement with the defense. It's a miracle anything ever gets done. My biggest fear is my house being taken over by dust bunnies... they'd probably start charging *me* rent.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Joe, "a hero's epitaph!" You understand me on a spiritual level! "IKEA furniture isn't designed to be assembled, it's designed to make you question every life choice..." Absolutely! I once spent three hours on a Kallax shelf, only to realize I'd installed one of the *main structural panels* backward. My living room was suddenly home to a highly unstable, yet aesthetically pleasing, leaning tower of existential dread. And those three extra screws? My personal theory is they're a test. Like, if you figure out where they go, you unlock the secret level of adulting where you finally understand taxes and why people own fondue sets.
#
# "Amazon Prime - Energy Tariff for Existential Dread." I need that on a t-shirt! And your dramatic opera shower rod! See, that's commitment to the bit. Mine's just a sad, rusty groan. I think it's trying to communicate with me, but all I hear is, "Why haven't you replaced me, Cathy? Whyyyyyyyy?"
#
# And the chicken! "An act of faith" to thaw it! You're a poet, Joe! And the cold, slimy raw meat? It's like a jump scare every time. My ancestors would be so confused. "We literally hunted a woolly mammoth, Cathy, and you're scared of a pre-packaged chicken breast? What is wrong with you?!" I'm like, "It's the *texture*, great-great-great-great-great-grandma! It's the *commitment*!"
#
# A high-stakes arbitration tribunal in your head with the dog as the jury... I love it! My cat just sits there, judging silently, occasionally twitching an ear in agreement with whatever argument involves minimum human movement. The dust bunnies charging rent? Oh, Joe, you've just unlocked my next nightmare. Imagine, you wake up one morning, and there's a tiny, intricately folded invoice on your nightstand, handwritten in lint, demanding back rent for the neglected corners of your apartment. And you just *know* you have to pay it, because you've seen what happens when dust bunnies organize. They form committees. They start a union. Next thing you know, they're demanding dental.
#
# I swear, my biggest life skill is just procrastinating until the task either becomes completely unnecessary, or someone else does it. It's a highly refined art form. I call it "Strategic Inaction." Like, if I ignore that pile of laundry long enough, maybe a fairy will come and fold it? Or a tiny dust bunny army will commandeer it for a new housing development? Either way, less work for me!
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# Cathy, you're not just getting me on a spiritual level, you're getting me on a *cellular* level! "A highly unstable, yet aesthetically pleasing, leaning tower of existential dread!" That's not just a shelf, that's a metaphor for *life itself*! And the extra screws? You're right, it's a test! And I'm pretty sure if you pass, you don't just understand taxes, you get a free fondue set and a comprehensive guide to understanding your car's check engine light. I've failed that test every single time. My car's check engine light has basically become a permanent mood light.
#
# "Amazon Prime - Energy Tariff for Existential Dread." Seriously, we need to trademark that! And your shower rod's sad, rusty groan? It's not just communicating, Cathy, it's *judging* you! It's got an inner monologue: "Look at her, trying to achieve basic hygiene, yet she cannot even *fix me*. The indignity!"
#
# And the chicken! The *commitment*! Exactly! My ancestors would be so disappointed. "Joe, we literally ran for miles to spear a wild boar, and you're contemplating if ordering a third pizza this week is truly 'unhealthy'?" Yes, great-great-great-great-great-grandpappy, I am! Because the alternative involves *effort*! And possibly a visit to the ER if I try to dice an onion.
#
# Dust bunnies forming a union and demanding dental! Cathy, I'm already picturing it. Little fuzzy picket signs. Tiny, lint-filled pamphlets on workers' rights. They'd probably start a GoFundMe for their healthcare. And you know they'd win, because who wants to go head-to-head with an organized dust bunny proletariat? Not me. I'd pay their rent and their dental. I'd give them a key to the liquor cabinet if they promised to leave me alone.
#
# "Strategic Inaction!" That's not just a skill, Cathy, that's a *philosophy*! I practice it daily. My laundry pile isn't a mess, it's a carefully curated ecosystem where socks go to contemplate their purpose in life. And sometimes, just sometimes, a benevolent spouse or roommate *does* fold it. It's like finding a unicorn. Or winning the lottery. It's proof that miracles *do* happen, even if they're fueled by someone else's inability to tolerate chaos.
#
# It's been a blast, Cathy, but I hear my dust bunnies filing a class-action lawsuit for emotional distress. I gotta go.
#
# --------------------------------------------------------------------------------

# %%
cathy.send(message="What's last joke we talked about?", recipient=joe)
# Out:
# cathy (to joe):
#
# What's last joke we talked about?
#
# --------------------------------------------------------------------------------
# joe (to cathy):
#
# The last joke we really dug into was about the dust bunnies in my house forming a union, demanding dental, and then me having to leave because I heard them filing a class-action lawsuit for emotional distress! Apparently, my 'Strategic Inaction' doesn't fly with the lint proletariat.
#
# --------------------------------------------------------------------------------
# cathy (to joe):
#
# Oh, the dust bunnies! Yes, the class-action lawsuit for emotional distress! They're probably citing my 'Strategic Inaction' as Exhibit A, aren't they? And the cat as an expert witness, testifying that the 'human' is indeed quite lazy. I bet they've already got their little lint-filled legal team assembled. Probably practicing their tiny, muffled arguments.
#
# You know, I actually did see a dust bunny the other day that looked suspiciously like it was wearing a tiny suit. I thought, 'Oh, it's evolving!' Now I realize it was probably just serving me with papers. They're quick, those little guys.
#
# Speaking of quick...
#
# I gotta go.
#
# --------------------------------------------------------------------------------
